# %%
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf
import utils.plot_3d as plot_3d 
from data_loading.noisy_bowl_loader import data_loading
from model.pca import PCA
   
x_train, x_test = data_loading()
    
with tf.Session() as sess:
    a = PCA(x_train, sess, dim_z=2)
    a.train()
        
    x_test_recon = a.recon(x_test)
    plot_3d.plot_3d(x_test)
    plot_3d.plot_3d(x_test_recon, title='PCA')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 01:31:42.040673 4611503552 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0726 01:31:42.047158 4611503552 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/pca_noisy_bowl_tensorflow/model/pca.py:46: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0726 01:31:42.047724 4611503552 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/pca_noisy_bowl_tensorflow/model/pca.py:50: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
