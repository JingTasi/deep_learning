# %% [markdown]
# [Mclnnes](https://www.youtube.com/watch?v=nq6iPZVUxZU)
# Ghodsi
# [1](https://www.youtube.com/watch?v=L-pQtGm3VS8&list=PLehuLRPyt1HzQoXEhtNuYTmd0aNQvtyAK)
# [2](https://www.youtube.com/watch?v=jeOEXCFK30M&list=PLehuLRPyt1HzQoXEhtNuYTmd0aNQvtyAK&index=2)
# Ng
# [14](https://www.youtube.com/watch?v=ey2PE5xi9-A)
# [15](https://www.youtube.com/watch?v=QGd06MTRMHs)
# ISLR
# [pdf](http://localhost:8888/notebooks/Dropbox/Paper/04_PCA_form_ISLR.pdf)
# Bouda
# [medium](https://medium.com/100-days-of-algorithms/day-92-pca-bdb66840a8fb)
# [github](https://github.com/coells/100days)

# %%
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf    
import utils.utils as utils 
from data_loading.mnist_flat_loader import data_loading 
from model.pca import PCA
    
x_train, _, _, x_test, _, _, _ = data_loading()
    
with tf.Session() as sess:
    a = PCA(x_train, sess, dim_z=100)
    a.train()
        
    img = x_test[0]
    img_recon = a.recon([img])
    utils.plot_one_image(img, (28,28))
    utils.plot_one_image(img_recon, (28,28))
        
    a.plot_16_original_and_recon(x_test[:16])
    a.plot_16_loading_vectors()
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/sungchul/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# gradient_step :  1000
# loss :            327.26068
# gradient_step :  2000
# loss :            261.83557
# gradient_step :  3000
# loss :            227.15561
# gradient_step :  4000
# loss :            212.88135
# gradient_step :  5000
# loss :            229.72073
# gradient_step :  6000
# loss :            242.48724
# gradient_step :  7000
# ...
